# %% [markdown]
# <font color="green"><h1><u>Exploratory Data Analysis(EDA) of Employee Details in ABC Company<font/>

# %% [markdown]
# The given dataset provides the information about employees within ABC Company.The dataset includes many informations such as 'Name','Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', and 'Salary'.By performing an EDA, we can arrive at a conclusion of data provided.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('EDA.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# <h3><u><b>Pre-processing of the Dataset<u/></b>

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.notnull()
# Out:
#      Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 0    True  True    True      True  True    True    True     True    True
# 1    True  True    True      True  True    True    True     True    True
# 2    True  True    True      True  True    True    True     True   False
# 3    True  True    True      True  True    True    True     True    True
# 4    True  True    True      True  True    True    True    False    True
# ..    ...   ...     ...       ...   ...     ...     ...      ...     ...
# 453  True  True    True      True  True    True    True     True    True
# 454  True  True    True      True  True    True    True    False    True
# 455  True  True    True      True  True    True    True    False    True
# 456  True  True    True      True  True    True    True     True    True
# 457  True  True    True      True  True    True    True     True    True
#
# [458 rows x 9 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Height'] = np.random.randint(150,180,len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     178     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     158     235
# 2     John Holland  Boston Celtics      30       SG   27     173     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     150     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     179     203
# 454      Raul Neto       Utah Jazz      25       PG   24     164     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     177     256
# 456    Jeff Withey       Utah Jazz      24        C   26     158     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %% [markdown]
# <u><b><h3>1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
team_employee_counts=df['Team'].value_counts()
print("Number of Employees in each team:\n")
print(team_employee_counts)
percentage_split=round((team_employee_counts/len(df))*100,2)
print("\nPercentage spliting:\n")
print(percentage_split)
# Out:
# Number of Employees in each team:
#
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# ...

# %%
team_table=pd.DataFrame({'Team':team_employee_counts.index, 'Number of Employees':team_employee_counts.values,'Percentage':percentage_split.values})
team_table
# Out:
#                       Team  Number of Employees  Percentage
# 0     New Orleans Pelicans                   19        4.15
# 1        Memphis Grizzlies                   18        3.93
# 2                Utah Jazz                   16        3.49
# 3          New York Knicks                   16        3.49
# 4          Milwaukee Bucks                   16        3.49
# 5            Brooklyn Nets                   15        3.28
# 6   Portland Trail Blazers                   15        3.28
# 7    Oklahoma City Thunder                   15        3.28
# 8           Denver Nuggets                   15        3.28
# 9       Washington Wizards                   15        3.28
# 10              Miami Heat                   15        3.28
# 11       Charlotte Hornets                   15        3.28
# 12           Atlanta Hawks                   15        3.28
# 13       San Antonio Spurs                   15        3.28
# 14         Houston Rockets                   15        3.28
# ...

# %%
plt.figure(figsize=(10,6))
plt.bar(team_table['Team'],team_table['Percentage'])
plt.title('Percentage of Employees in each team')
plt.xlabel('Team')
plt.ylabel('Percentage')
plt.xticks(rotation=45 ,ha='right')
plt.show()

# %% [markdown]
# <b>Data story<b/> - The graph shows a quick overview of percentage of Employees in each team in ABC Company.New Orleans Pelicans has more employees whereas Orlando Magic and Minnesota Timberwolves has the least number of employees

# %% [markdown]
# <u><b><h3>2.Segregate the employees w.r.t different positions.

# %%
position=df['Position'].value_counts()
print(position)
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plt.title('Position Segregation of Employees')
sns.countplot(x='Position',data=df,hue='Position')
plt.show()

# %% [markdown]
# <b>Data Story-The graph displays the count of employees in respected positions.'SG' position has more employees with count of 102 and the 'C' position has the least employees with a count of 79<b/>

# %% [markdown]
# <u><b><h3>3.Find from which age group most of the employees belong to.

# %%
df['Age'].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Age',data=df,hue='Age')
plt.show()

# %%
bins=[18,20,25,30,35,40]
labels=['18-20','20-25','25-30','30-35','35-40']
df['age_groups']=pd.cut(df['Age'],bins=bins,labels=labels,right=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary age_groups
# 0                Texas  7730337.0      20-25
# ...

# %%
age_groups=age_groups.value_counts()
age_groups
# Out:
# Age
# 20-25    179
# 25-30    167
# 30-35     68
# 35-40     23
# 18-20     21
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='age_groups',data=df,hue='age_groups')
plt.show()

# %% [markdown]
# <b>Data Story- As shown in the above graph.We can clearly see that the number of employees are more in the age category of 20-25 with 179 employees and 165 employees in the age category of 25-30.<b/>

# %% [markdown]
# <u><b><h3>4.Find out under which team and position, spending in terms of salary is high.

# %%
high_spending=df.groupby(['Team','Position'])['Salary'].sum().idxmax()
high_spending
# Out:
# ('Los Angeles Lakers', 'SF')

# %% [markdown]
# <b>The team with the highest spending in terms of salary is 'Los Angeles Lakers' and the position is 'SF'<b/>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Team',y='Salary',hue='Position',data=df[df['Team']== high_spending[0]])
plt.title('Salary Distribution in High Spending Team and Position')
plt.xlabel('Team')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# <b>Data Story-As shown in the above graph,we can clearly see that SF position in Los Angeles Lakers Team has the high spending in salary distribution.

# %% [markdown]
# <u><b><h3>5.Find if there is any correlation between age and salary , represent it visually.

# %%
correlation=df[['Age','Salary']].corr()
correlation
# Out:
#              Age    Salary
# Age     1.000000  0.214009
# Salary  0.214009  1.000000

# %%
plt.figure(figsize=(4,3))
sns.heatmap(correlation,annot=True,cmap='coolwarm',fmt=".2f", linewidths=.5)
plt.title('Correlation between Age and Salary')
plt.show()

# %% [markdown]
# <b>Data Story - The heatmap represents the correlation matrix between Age and Salary
